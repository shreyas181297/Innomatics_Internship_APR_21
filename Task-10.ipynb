# %% [markdown]
# <B>Exploratory Data Analysis (EDA)</B> is an approach/philosophy for data analysis that employs a variety of techniques (mostly graphical) to
# <ol type ="1"><li>
# maximize insight into a data set;<li>
# uncover underlying structure;<li>
# extract important variables;<li>
# detect outliers and anomalies;<li>
# test underlying assumptions;<li>
# develop parsimonious models;<li>
# determine optimal factor settings.</ol>
# <p>
#
# Most EDA techniques are graphical in nature with a few quantitative techniques. The reason for the heavy reliance on graphics is that by its very nature the main role of EDA is to open-mindedly explore, and graphics gives the analysts unparalleled power to do so, enticing the data to reveal its structural secrets, and being always ready to gain some new, often unsuspected, insight into the data. In combination with the natural pattern-recognition capabilities that we all possess, graphics provides, of course, unparalleled power to carry this out.
# The particular graphical techniques employed in EDA are often quite simple, consisting of various techniques of:
# <ol type ="1"><li>
# Plotting the raw data (such as data traces, histograms, bihistograms, probability plots, lag plots, block plots, and Youden plots.<li>
# Plotting simple statistics such as mean plots, standard deviation plots, box plots, and main effects plots of the raw data.<li>
# Positioning such plots so as to maximize our natural pattern-recognition abilities, such as using multiple plots per page.</ol>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <B>Step - 1</B> : Introduction and Give a detailed data description and objective
# <p> This dataset was taken from Aspiring Minds for performing EDA (Exploratory Data Analysis).
#     The main motive from this assignment is to understand how EDA can be carried out and its insight can help to understand more about the data.<p>
# <B>Step - 2</B> : Import the data and display the head, shape and description of the data.

# %%
df =pd.read_excel('EDA.xlsx')

df
# Out:
#      Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0         train  203097   420000 2012-06-01              present
# 1         train  579905   500000 2013-09-01              present
# 2         train  810601   325000 2014-06-01              present
# 3         train  267447  1100000 2011-07-01              present
# 4         train  343523   200000 2014-03-01  2015-03-01 00:00:00
# ...         ...     ...      ...        ...                  ...
# 3993      train   47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994      train  752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995      train  355888   320000 2013-07-01              present
# 3996      train  947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997      train  324966   400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 0         senior quality engineer         Bangalore      f 1990-02-19
# ...

# %% [markdown]
# As the first column which is Unnamed but it contains all redundant entries as "train", so to get correct understandig we will drop this column, and we will print the result with first 5 rows using df.head() and last 5 rows using df.tail() functions

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
df.head()
# Out:
#        ID   Salary        DOJ                  DOL               Designation  \
# 0  203097   420000 2012-06-01              present   senior quality engineer
# 1  579905   500000 2013-09-01              present         assistant manager
# 2  810601   325000 2014-06-01              present          systems engineer
# 3  267447  1100000 2011-07-01              present  senior software engineer
# 4  343523   200000 2014-03-01  2015-03-01 00:00:00                       get
#
#      JobCity Gender        DOB  10percentage                         10board  \
# 0  Bangalore      f 1990-02-19          84.3  board ofsecondary education,ap
# 1     Indore      m 1989-10-04          85.4                            cbse
# 2    Chennai      f 1992-08-03          85.0                            cbse
# 3    Gurgaon      m 1989-12-05          85.6                            cbse
# 4    Manesar      m 1991-02-27          78.0                            cbse
#
# ...

# %%
df.tail()
# Out:
#           ID  Salary        DOJ                  DOL  \
# 3993   47916  280000 2011-10-01  2012-10-01 00:00:00
# 3994  752781  100000 2013-07-01  2013-07-01 00:00:00
# 3995  355888  320000 2013-07-01              present
# 3996  947111  200000 2014-07-01  2015-01-01 00:00:00
# 3997  324966  400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 3993            software engineer        New Delhi       m 1987-04-15
# 3994             technical writer         Hyderabad      f 1992-08-27
# 3995  associate software engineer         Bangalore      m 1991-07-03
# 3996           software developer  Asifabadbanglore      f 1992-03-20
# 3997      senior systems engineer           Chennai      f 1991-02-26
#
#       10percentage      10board  ...  ComputerScience  MechanicalEngg  \
# 3993         52.09         cbse  ...               -1              -1
# 3994         90.00  state board  ...               -1              -1
# ...

# %% [markdown]
# Printing shape, decription and nature of data, null entries for each colums

# %%
print(df.shape)
print(df.isnull().sum())
print(df.dtypes)
# Out:
# (3998, 38)
# ID                       0
# Salary                   0
# DOJ                      0
# DOL                      0
# Designation              0
# JobCity                  0
# Gender                   0
# DOB                      0
# 10percentage             0
# 10board                  0
# 12graduation             0
# 12percentage             0
# 12board                  0
# CollegeID                0
# CollegeTier              0
# Degree                   0
# Specialization           0
# collegeGPA               0
# CollegeCityID            0
# CollegeCityTier          0
# CollegeState             0
# GraduationYear           0
# English                  0
# Logical                  0
# Quant                    0
# Domain                   0
# ComputerProgramming      0
# ElectronicsAndSemicon    0
# ComputerScience          0
# MechanicalEngg           0
# ElectricalEngg           0
# TelecomEngg              0
# CivilEngg                0
# conscientiousness        0
# ...

# %% [markdown]
# Using df.desbribe() to return all description of data , which includes mean, median, percentiles ranges, minimum value, maximum value and null entries

# %%
df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %% [markdown]
# <B>Step - 3 </B>- Univariate Analysis -> PDF, Histograms, Boxplots, Countplots, etc..
# <ul><li>Find the outliers in each numerical column<li>
# Understand the probability and frequency distribution of each numerical column<li>
# Understand the frequency distribution of each categorical Variable/Column</ul>

# %% [markdown]
# As our data does not include any missing values or redundant entries from initial inspection we can go ahead to perform Univariate analysis. Univariate analysis is perhaps the simplest form of statistical analysis. Like other forms of statistics, it can be inferential or descriptive. The key fact is that only one variable is involved.
#
# <p> Now we will plot boxplots to get idea about outliers in the dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,10))
num_features = df.select_dtypes(include=['int64']).columns
t=['Salary', '12graduation','CollegeTier','English','Logical','Quant']
print(num_features)
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.boxplot(df[t[i]])
    plt.title(t[i],color="r",fontsize=15)
# Out:
# Index(['ID', 'Salary', '12graduation', 'CollegeID', 'CollegeTier',
#        'CollegeCityID', 'CollegeCityTier', 'GraduationYear', 'English',
#        'Logical', 'Quant', 'ComputerProgramming', 'ElectronicsAndSemicon',
#        'ComputerScience', 'MechanicalEngg', 'ElectricalEngg', 'TelecomEngg',
#        'CivilEngg'],
#       dtype='object')

# %% [markdown]
# As we can see from the above plots there is presence of many outliers in the data, which we need to remove by suitable menthod else they might give bad skewed results in the final caluculations

# %% [markdown]
# Now plotting Histograms for counting data points in each category

# %%
plt.figure(figsize=(7,5))
df['Gender'].hist()
plt.figure(figsize=(7,5))
df['Degree'].hist()
plt.figure(figsize=(7,5))
df['Specialization'].hist()

# %% [markdown]
# Using histogram plot for categorical variables we can get idea about the distribution pattern in each column variables

# %% [markdown]
# Performing PDF analysis of the factors : <ul><li>conscientiousnes<li>agreeableness<li>extraversion<li>nueroticism<li>openess_to_experience</ul>

# %%
plt.figure(figsize=(18,10))
plt.subplot(244)
sns.distplot(df['agreeableness'])
plt.title("Agreeableness Score")
plt.subplot(241)
sns.distplot(df['extraversion'])
plt.title("Extraversied Score")
plt.subplot(242)
sns.distplot(df['nueroticism'])
plt.title("Neurotics score")
plt.subplot(243)
sns.distplot(df['openess_to_experience'])
plt.title("Openess to Experience score")
plt.show()

# %% [markdown]
# As we can see from above plots the data is normally distributed for the decision variables hence we dont need to perform any operation to standardize the data

# %% [markdown]
# <B>Step - 4 </B>- Bivariate Analysis
# <ul><li>Discover the relationships between numerical columns using Scatter plots, hexbin plots,
# pair plots, etc..
# <li>Identify the patterns between categorical and numerical columns using swarmplot,
# boxplot, barplot, etc..
# </ul>

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')
plt.show()

# %% [markdown]
# Using the correaltion heatmap we can get idea about the relationship between variables, which shows dark color scheme have good correaltion while the yellow color shows no or very less correlation.<p>
# Now plotting kdeplot to understand the how replationship of 10th percentage and 12th percentage does take place

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(df['12percentage'],df['10percentage'])
plt.show()

# %% [markdown]
# Now, Analysis of Gender vs salary by factorplot analysis<ul>
# <li>Male with MCA degree has lowest salary<li>Female with M.tech degree has highest and with M.Sc has lowest salary.</ul>

# %%
plt.figure(figsize=(8,5))
sns.factorplot(x='Gender', y='Salary',hue='Degree',kind='bar',data=df)
plt.show()

# %%
sns.jointplot(x=df['12percentage'],y=df['10percentage'],kind='hex',data=df)

# %%
plt.figure(figsize = (10,7))
sns.barplot('Specialization', 'Salary', data =df, color = 'g')
plt.xticks(rotation=90)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# We can see polymer technology receives highest salary and electronics receives lowest salary.
# <p> now performing salary with computer programming

# %%
plt.figure(figsize = (10,7))
sns.lineplot('ComputerProgramming', 'Salary', data =df, color = 'y')

# %%
# find the distribution pof gender wrto different classes of salary using cross tab ?
pd.crosstab([df.Gender],[df.Salary],margins=True)
# Out:
# Salary  35000  40000  45000  50000  55000  60000  65000  70000  75000  80000  \
# Gender
# f           1      0      1      3      0      3      2      2      1      2
# m           2      2      3      2      1     10      2      5      5      9
# All         3      2      4      5      1     13      4      7      6     11
#
# Salary  ...  2000000  2020000  2050000  2300000  2500000  2600000  3000000  \
# Gender  ...
# f       ...        0        0        0        0        0        0        0
# m       ...        4        1        1        1        1        1        1
# All     ...        4        1        1        1        1        1        1
#
# Salary  3500000  4000000   All
# Gender
# f             1        0   957
# m             0        2  3041
# All           1        2  3998
#
# [3 rows x 178 columns]

# %% [markdown]
# We have succesfully performed the croos tabulation of salary when we consider gender male and female.

# %%
#extract the salary_class of each candidate followed by their id,using pivot() 
df.pivot_table(index='Salary',columns='CollegeCityTier',margins=True)
# Out:
#                 10percentage                       12graduation               \
# CollegeCityTier            0          1        All            0            1
# Salary
# 35000              87.000000  85.300000  86.433333  2007.000000  2010.000000
# 40000              79.200000  64.000000  71.600000  2009.000000  2008.000000
# 45000              71.800000  72.500000  72.150000  2008.500000  2008.500000
# 50000              71.995000  82.000000  73.996000  2007.500000  2008.000000
# 55000              75.060000        NaN  75.060000  2009.000000          NaN
# ...                      ...        ...        ...          ...          ...
# 2600000            86.600000        NaN  86.600000  2007.000000          NaN
# 3000000            89.000000        NaN  89.000000  2009.000000          NaN
# 3500000            76.800000        NaN  76.800000  2009.000000          NaN
# 4000000            53.000000  90.830000  71.915000  2004.000000  2005.000000
# ...

# %% [markdown]
# The above pivot table gives us idea about the difference of salary with change in Tier of the college, salary increases as the tier of college change

# %%
df.plot(x='agreeableness',y='extraversion',kind='scatter')
plt.show()

# %% [markdown]
# Understanding Relation between extraversion and agreebleness using scatter plot

# %% [markdown]
# Orange is for Male and Blue is for Female
# Salary for both the genders are in high density between the level 0.0 to 1.5 for B.Tech/B.E
# 0.0 to 1.0 for MCA
# Around half of MCA is for M.Tech/M.E
# Very least in density is for M.Sc

# %% [markdown]
# <B>Step-5 Research question</B>:
# Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.” Test this claim with the data given to you.Is there a relationship between gender and specialisation? (i.e. Does the preference of Specialisation depend on the Gender?)
# <p>
# $Alternate hypothesis:$$$\ H1 = They\ are\ dependent$$Null hypothesis:$$\ H0= They\ are\ independent$$
# <p>
# Let us use hypothesis testing for this question find out the claim

# %% [markdown]
# Plotting specialization vs Gender graph and crosstabulation to get idea about salary

# %%
pd.crosstab(df['Specialization'],df['Gender'],margins = True)
# Out:
# Gender                                         f     m   All
# Specialization
# aeronautical engineering                       1     2     3
# applied electronics and instrumentation        2     7     9
# automobile/automotive engineering              0     5     5
# biomedical engineering                         2     0     2
# biotechnology                                  9     6    15
# ceramic engineering                            0     1     1
# chemical engineering                           1     8     9
# civil engineering                              6    23    29
# computer and communication engineering         0     1     1
# computer application                          59   185   244
# computer engineering                         175   425   600
# computer networking                            0     1     1
# computer science                               1     1     2
# computer science & engineering               183   561   744
# ...

# %%
sns.swarmplot(x='Degree', y='Salary', hue= "Gender",data=df.head(300))
plt.show()

# %% [markdown]
# As we can see from above swarmplot the gender will affect the specilaization choosen by the individual

# %%
print(Freshers_res)
print("mean",Freshers_res.Salary.mean())
print("min",Freshers_res.Salary.min())
print("max",Freshers_res.Salary.max())
# Out:
#       Exp      desig        Specialization  Salary
# 19    0.4   engineer  computer engineering  325000
# 103   0.4    analyst  computer engineering  300000
# 343   0.9   engineer  computer engineering  300000
# 497   0.0  associate  computer engineering  120000
# 578   0.4    analyst  computer engineering  305000
# 885  -0.1   engineer  computer engineering  315000
# 1060  0.6   engineer  computer engineering   50000
# 1510  0.4   engineer  computer engineering  560000
# 1850  0.4    analyst  computer engineering  400000
# 1908  0.9   engineer  computer engineering  335000
# 1915  0.0   engineer  computer engineering  300000
# 1945  0.4   engineer  computer engineering  220000
# 2026  1.0   engineer  computer engineering  395000
# 2212  0.5   engineer  computer engineering  210000
# 2351  0.9   engineer  computer engineering  345000
# 2355  0.9   engineer  computer engineering  380000
# 2702  0.5   engineer  computer engineering  120000
# ...

# %% [markdown]
# As we can see from above list the salary mean is around 3 lacks hence claim 1 is satisfied with the given data.

# %% [markdown]
# <B>Step 6: Conclusion</B>
# <p> Conclusion:
# From above research Hypothesis is rejected that means Both Specialization and Gender are dependent on each other.

# %% [markdown]
# <B>Step 7</b>:<ol type="1"> <li>Does the individual city and tier of college affect the salary or the city of college plays a better role in this analysis<li> Does B.E. grad earn more than other graduated in future<li> Are 10th and 12th percentage matter while choosing future study and is it dependant in gender<li> For which role can male earn less than females usually <li> factor openess to experience can it depend upon college tier and city of student.</ol>
